# %%
import keras
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
img_path = "/content/cat.png"
img = keras.utils.load_img(img_path, target_size=(224, 224))
x = keras.utils.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
print(f'Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Predicted: [('n02123045', 'tabby', np.float32(0.79550606)), ('n02123159', 'tiger_cat', np.float32(0.16826583)), ('n02124075', 'Egyptian_cat', np.float32(0.022926867))]

# %%
img_path = "/content/dog.jpg"
img = keras.utils.load_img(img_path,target_size=(224, 224))
x = keras.utils.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
pred2 = model.predict(x)
print(f'Predicted:', decode_predictions(pred2, top=5)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# Predicted: [('n02099601', 'golden_retriever', np.float32(0.9712043)), ('n02099712', 'Labrador_retriever', np.float32(0.01570626)), ('n02111500', 'Great_Pyrenees', np.float32(0.008299651)), ('n02104029', 'kuvasz', np.float32(0.0031338765)), ('n02099267', 'flat-coated_retriever', np.float32(0.00025008744))]
